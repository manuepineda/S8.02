# %% [markdown]
# TASCA 8.02

# %% [markdown]
# #EXCERCICI 1
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #Excercici 2
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #EXCERCICI 3
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #EXCERCICI 4
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #EXCERCICI 5
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #EXCERCICI 6
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #EXCERCICI 7
#
# ![image.png](attachment:image.png)
